# %%
from functions import *

# %%
file = "test"
time = 10
get_new_data(time,file)
global_analyse("D:\Data_PKL\{}".format(file))
# Out:
# CONNECT: E5D608D31715
# Old emissivity: 0.9700000286102295
# New emissivity: 0.9700000286102295
# frame available: E5D608D31715 (size: 320x240)
# frame available: E5D608D31715 (size: 320x240)
# frame available: E5D608D31715 (size: 320x240)
# frame available: E5D608D31715 (size: 320x240)
# frame available: E5D608D31715 (size: 320x240)
# frame available: E5D608D31715 (size: 320x240)
# frame available: E5D608D31715 (size: 320x240)
# frame available: E5D608D31715 (size: 320x240)
# frame available: E5D608D31715 (size: 320x240)
# frame available: E5D608D31715 (size: 320x240)
# frame available: E5D608D31715 (size: 320x240)
# frame available: E5D608D31715 (size: 320x240)
# frame available: E5D608D31715 (size: 320x240)
# frame available: E5D608D31715 (size: 320x240)
# frame available: E5D608D31715 (size: 320x240)
# frame available: E5D608D31715 (size: 320x240)
# frame available: E5D608D31715 (size: 320x240)
# frame available: E5D608D31715 (size: 320x240)
# ...
